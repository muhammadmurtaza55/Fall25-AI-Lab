# %% [markdown]
# # **Code for LUHN Algorithm**

# %%
def luhn_check(card_number):
    card_number = card_number.replace(" ", "") 
    total = 0
    reverse_digits = card_number[::-1]

    for i, digit in enumerate(reverse_digits):
        n = int(digit)
        if i % 2 == 1: 
            n = n * 2
            if n > 9:  
                n -= 9
        total += n

    return total % 10 == 0


card = "4539578763621486"  
if luhn_check(card):
    print("Valid Card Number")
else:
    print("Invalid Card Number")
# Out:
# Valid Card Number

# %% [markdown]
# # **Write a python program to remove punctuations from the given string**

# %%
def remove_punctuations(text):
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    result = ""
    for char in text:
        if char not in punctuations:
            result += char
    return result


sentence = "Hello!!!, welcome to: Python's world???"
print(remove_punctuations(sentence))
# Out:
# Hello welcome to Pythons world

# %% [markdown]
# # **Write a python program to sort the sentence in alphabetical order**

# %%
def sort_sentence(sentence):
    words = sentence.split()
    words.sort() 
    return " ".join(words)


sentence = "python is a powerful and easy language"
print(sort_sentence(sentence))
# Out:
# a and easy is language powerful python
